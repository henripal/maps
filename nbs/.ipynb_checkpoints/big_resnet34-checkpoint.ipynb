# %% [markdown]
# # Lesson 1  Homework - Where's your city?

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
import os
import random
from collections import defaultdict
import pandas as pd
import re

# %% [markdown]
# ## Looking at the data

# %%
torch.cuda.set_device(0)

# %%
path = Path('/home/henripal/projects/maps/scraper/')

# %%
path.ls()
# Out:
# [PosixPath('/home/henripal/projects/maps/scraper/scraper'),
#  PosixPath('/home/henripal/projects/maps/scraper/img'),
#  PosixPath('/home/henripal/projects/maps/scraper/data')]

# %%
path_img = path/'img'

# %%
fnames = get_image_files(path_img)

# %%
city_to_file = defaultdict(list)

# %%
for fname in fnames:
    city_to_file[fname.stem[:-1]].append(fname)

# %%
city_list = list(city_to_file.keys())

# %%
random.shuffle(city_list)

# %%
train_pct = 0.80
train_idx = int(len(city_list) * train_pct) ; train_idx

# %%
target_paths = []
target_labels = []
pat = r',+([A-z_+-ô\"\'\(\)]+)\d+.png$'
for train_city in city_list[:train_idx]:
    for train_file in city_to_file[train_city]:
        target_paths.append(str(Path('train',train_file.name)))
        country_name= re.search(pat, str(train_file)).group(1)
        target_labels.append(country_name)
for train_city in city_list[train_idx:]:
    for train_file in city_to_file[train_city]:
        target_paths.append(str(Path('test',train_file.name)))
        country_name= re.search(pat, str(train_file)).group(1)
        target_labels.append(country_name)

# %%
df = pd.DataFrame({
    'label': target_labels,
    'name': target_paths,
})

# %%
df = df[['name', 'label']]

# %%
df

# %%
df.to_csv(path_img/'labels.csv',index=False)

# %%
for train_city in city_list[:train_idx]:
    for train_file in city_to_file[train_city]:
        start_file = str(train_file)
        target_file = str(train_file.parent/'train'/train_file.name)
        os.rename(start_file, target_file)

# %%
for train_city in city_list[train_idx:]:
    for train_file in city_to_file[train_city]:
        start_file = str(train_file)
        target_file = str(train_file.parent/'test'/train_file.name)
        os.rename(start_file, target_file)

# %%
data = ImageDataBunch.from_csv(path_img, ds_tfms=get_transforms(), size=224, bs=256)
data.normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c

# %% [markdown]
# ## Training: resnet34

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(7)
# Out:
# Total time: 14:31
# epoch  train_loss  valid_loss  error_rate
# 1      2.431352    1.926598    0.475252    (02:02)
# 2      1.744314    1.485835    0.399664    (02:04)
# 3      1.533194    1.306648    0.357447    (02:04)
# 4      1.385806    1.182488    0.330347    (02:04)
# 5      1.251767    1.113583    0.310470    (02:04)
# 6      1.160208    1.065986    0.301008    (02:07)
# 7      1.132802    1.065085    0.300840    (02:04)

# %%
learn.save('resnet34-big-stage-1')

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=2)
# Out:
# [('Pakistan', 'India', 79),
#  ('Canada', 'United+States', 58),
#  ('Indonesia', 'Philippines', 50),
#  ('Italy', 'Spain', 49),
#  ('Germany', 'France', 41),
#  ('Russia', 'Ukraine', 38),
#  ('Poland', 'Germany', 37),
#  ('France', 'Spain', 36),
#  ('Ukraine', 'Russia', 36),
#  ('Portugal', 'Spain', 34),
#  ('Bangladesh', 'India', 34),
#  ('Germany', 'United+Kingdom', 32),
#  ('Czech+Republic', 'Germany', 32),
#  ('Kazakhstan', 'Russia', 30),
#  ('France', 'Germany', 27),
#  ('Turkey', 'Spain', 27),
#  ('Brazil', 'Philippines', 24),
#  ('France', 'United+Kingdom', 23),
#  ('Spain', 'Italy', 22),
#  ('India', 'Philippines', 22),
#  ('Germany', 'Poland', 21),
#  ('Belarus', 'Russia', 21),
#  ('India', 'Pakistan', 20),
#  ('Ireland', 'United+Kingdom', 20),
#  ('India', 'Thailand', 19),
#  ('Netherlands', 'United+Kingdom', 19),
#  ('Algeria', 'Italy', 18),
#  ('Germany', 'United+States', 18),
#  ('India', 'Mexico', 18),
#  ('Colombia', 'Philippines', 18),
#  ('Netherlands', 'Germany', 18),
#  ('Germany', 'Belgium', 17),
#  ('Germany', 'Netherlands', 17),
#  ('Guatemala', 'Mexico', 17),
#  ('Japan', 'United+States', 16),
#  ('Malaysia', 'Philippines', 16),
#  ('Colombia', 'Brazil', 16),
#  ('Colombia', 'Mexico', 16),
#  ('United+Kingdom', 'Germany', 15),
#  ('Brazil', 'Mexico', 14),
#  ('South+Africa', 'Brazil', 14),
#  ('Sweden', 'Poland', 14),
#  ('Belgium', 'Germany', 14),
#  ('Dominican+Republic', 'Mexico', 14),
#  ('New+Zealand', 'Australia', 14),
#  ('Thailand', 'Philippines', 13),
#  ('Algeria', 'Spain', 13),
#  ('Venezuela', 'Mexico', 13),
#  ('Russia', 'United+States', 13),
#  ('Philippines', 'Indonesia', 13),
#  ('Italy', 'Mexico', 13),
#  ('United+States', 'United+Kingdom', 13),
#  ('United+States', 'Canada', 13),
#  ('Ecuador', 'Mexico', 13),
#  ('Lithuania', 'Russia', 13),
#  ('Uruguay', 'Argentina', 13),
#  ('Algeria', 'India', 12),
#  ('China', 'India', 12),
#  ('Tunisia', 'Mexico', 12),
#  ('Myanmar', 'India', 12),
#  ('Tanzania', 'India', 12),
#  ('Switzerland', 'France', 12),
#  ('Nepal', 'India', 12),
#  ('United+Kingdom', 'Netherlands', 11),
#  ('Hungary', 'Romania', 11),
#  ('France', 'Italy', 11),
#  ('Italy', 'France', 11),
#  ('India', 'Indonesia', 11),
#  ('United+States', 'Mexico', 11),
#  ('Romania', 'Russia', 11),
#  ('Turkey', 'Algeria', 11),
#  ('Nigeria', 'India', 11),
#  ('Nigeria', 'Tanzania', 11),
#  ('Greece', 'Mexico', 11),
#  ('Tanzania', 'Brazil', 11),
#  ('Moldova', 'Ukraine', 11),
#  ('Switzerland', 'Germany', 11),
#  ('Brazil', 'Indonesia', 10),
#  ('China', 'Thailand', 10),
#  ('China', 'Russia', 10),
#  ('Poland', 'Russia', 10),
#  ('Argentina', 'Mexico', 10),
#  ('Denmark', 'Germany', 10),
#  ('Libya', 'Algeria', 10),
#  ('Chile', 'Argentina', 10),
#  ('Brazil', 'United+States', 9),
#  ('Algeria', 'Turkey', 9),
#  ('China', 'Philippines', 9),
#  ('France', 'Belgium', 9),
#  ('Mexico', 'Argentina', 9),
#  ('Bulgaria', 'Turkey', 9),
#  ('Vietnam', 'India', 9),
#  ('Peru', 'Mexico', 9),
#  ('Iran', 'Mexico', 9),
#  ('North+Korea', 'China', 9),
#  ('Bolivia', 'Brazil', 9),
#  ('China', 'Spain', 8),
#  ('United+Kingdom', 'France', 8),
#  ('Poland', 'France', 8),
#  ('Argentina', 'Brazil', 8),
#  ('Philippines', 'Brazil', 8),
#  ('Philippines', 'Thailand', 8),
#  ('Italy', 'Germany', 8),
#  ('India', 'Brazil', 8),
#  ('Ghana', 'Nigeria', 8),
#  ('Madagascar', 'Philippines', 8),
#  ('Madagascar', 'India', 8),
#  ('United+States', 'Spain', 8),
#  ('United+States', 'Japan', 8),
#  ('Czech+Republic', 'Poland', 8),
#  ('Romania', 'Ukraine', 8),
#  ('Vietnam', 'Thailand', 8),
#  ('Cambodia', 'Thailand', 8),
#  ('Finland', 'Poland', 8),
#  ('Finland', 'Russia', 8),
#  ('Belarus', 'Poland', 8),
#  ('Nigeria', 'Brazil', 8),
#  ('Egypt', 'India', 8),
#  ('Azerbaijan', 'Mexico', 8),
#  ('Senegal', 'India', 8),
#  ('Paraguay', 'Brazil', 8),
#  ('Brazil', 'Colombia', 7),
#  ('Algeria', 'Mexico', 7),
#  ('Algeria', 'Libya', 7),
#  ('United+Kingdom', 'United+States', 7),
#  ('Hungary', 'Poland', 7),
#  ('France', 'Netherlands', 7),
#  ('Russia', 'Poland', 7),
#  ('Ukraine', 'Poland', 7),
#  ('India', 'Italy', 7),
#  ('United+States', 'Germany', 7),
#  ('Indonesia', 'Brazil', 7),
#  ('Colombia', 'Cuba', 7),
#  ('Vietnam', 'Philippines', 7),
#  ('Vietnam', 'Indonesia', 7),
#  ('Iraq', 'Afghanistan', 7),
#  ('Peru', 'India', 7),
#  ('Zambia', 'Tanzania', 7),
#  ('Sweden', 'Russia', 7),
#  ('Belgium', 'United+Kingdom', 7),
#  ('Belgium', 'Netherlands', 7),
#  ('Somalia', 'India', 7),
#  ('Syria', 'Algeria', 7),
#  ('Lithuania', 'Poland', 7),
#  ('Guatemala', 'Philippines', 7),
#  ('Nicaragua', 'Philippines', 7),
#  ('Brazil', 'Thailand', 6),
#  ('Brazil', 'Chile', 6),
#  ('Algeria', 'Tunisia', 6),
#  ('South+Korea', 'China', 6),
#  ('Venezuela', 'Philippines', 6),
#  ('Germany', 'Italy', 6),
#  ('Ukraine', 'Romania', 6),
#  ('India', 'Tanzania', 6),
#  ('Ghana', 'India', 6),
#  ('Indonesia', 'Thailand', 6),
#  ('Slovakia', 'Romania', 6),
#  ('Romania', 'Hungary', 6),
#  ('Vietnam', 'China', 6),
#  ('Turkey', 'Brazil', 6),
#  ('Turkey', 'China', 6),
#  ('Turkey', 'Mexico', 6),
#  ('South+Africa', 'Australia', 6),
#  ('Iran', 'Tunisia', 6),
#  ('Greece', 'Italy', 6),
#  ('Greece', 'Turkey', 6),
#  ('Azerbaijan', 'Russia', 6),
#  ('Azerbaijan', 'Ukraine', 6),
#  ('Ivory+Coast', 'Nigeria', 6),
#  ('Tanzania', 'Philippines', 6),
#  ('Syria', 'Tunisia', 6),
#  ('Serbia', 'Romania', 6),
#  ('Zimbabwe', 'Tanzania', 6),
#  ('Austria', 'Germany', 6),
#  ('Switzerland', 'Netherlands', 6),
#  ('Honduras', 'Mexico', 6),
#  ('Chile', 'Brazil', 6),
#  ('Nicaragua', 'Mexico', 6),
#  ('Kyrgyzstan', 'Mexico', 6),
#  ('Latvia', 'Russia', 6),
#  ('Brazil', 'Argentina', 5),
#  ('Brazil', 'Spain', 5),
#  ('Algeria', 'Morocco', 5),
#  ('China', 'United+States', 5),
#  ('Poland', 'Ukraine', 5),
#  ('Russia', 'Brazil', 5),
#  ('Russia', 'Philippines', 5),
#  ('Russia', 'India', 5),
#  ('Spain', 'Japan', 5),
#  ('Spain', 'Portugal', 5),
#  ('Spain', 'United+States', 5),
#  ('Mexico', 'United+States', 5),
#  ('Japan', 'Philippines', 5),
#  ('Italy', 'United+States', 5),
#  ('India', 'United+States', 5),
#  ('India', 'Myanmar', 5),
#  ('India', 'Bangladesh', 5),
#  ('Sri+Lanka', 'India', 5),
#  ('Bulgaria', 'Serbia', 5),
#  ('Colombia', 'Ecuador', 5),
#  ('Turkey', 'Italy', 5),
#  ('Turkey', 'Romania', 5),
#  ('Turkey', 'Syria', 5),
#  ('Cambodia', 'Philippines', 5),
#  ('Australia', 'United+States', 5),
#  ('Peru', 'Brazil', 5),
#  ('Nigeria', 'Philippines', 5),
#  ('Nigeria', 'Kenya', 5),
#  ('Croatia', 'Hungary', 5),
#  ('Dominican+Republic', 'Brazil', 5),
#  ('Tanzania', 'Nigeria', 5),
#  ('Kosovo', 'Brazil', 5),
#  ('Bosnia+and+Herzegovina', 'Serbia', 5),
#  ('Benin', 'Nigeria', 5),
#  ('Slovenia', 'Slovakia', 5),
#  ('Georgia', 'Russia', 5),
#  ('Kazakhstan', 'Ukraine', 5),
#  ('Uzbekistan', 'Russia', 5),
#  ('Chile', 'Mexico', 5),
#  ('Estonia', 'Russia', 5),
#  ('Haiti', 'Mexico', 5),
#  ('Brazil', 'Australia', 4),
#  ('Algeria', 'Philippines', 4),
#  ('China', 'Brazil', 4),
#  ('China', 'Malaysia', 4),
#  ('China', 'Turkey', 4),
#  ('Hungary', 'Russia', 4),
#  ('Poland', 'Czech+Republic', 4),
#  ('Germany', 'Russia', 4),
#  ('Spain', 'France', 4),
#  ('Mexico', 'Spain', 4),
#  ('Japan', 'Mexico', 4),
#  ('Philippines', 'Spain', 4),
#  ('Philippines', 'Italy', 4),
#  ('Italy', 'Portugal', 4),
#  ('Macedonia', 'Romania', 4),
#  ('India', 'China', 4),
#  ('India', 'Spain', 4),
#  ('India', 'Madagascar', 4),
#  ('India', 'Colombia', 4),
#  ('India', 'Kenya', 4),
#  ('United+States', 'Australia', 4),
#  ('Indonesia', 'United+States', 4),
#  ('Slovakia', 'Poland', 4),
#  ('Malaysia', 'Thailand', 4),
#  ('Sri+Lanka', 'Philippines', 4),
#  ('Sri+Lanka', 'Indonesia', 4),
#  ('Colombia', 'Indonesia', 4),
#  ('Pakistan', 'Algeria', 4),
#  ('Pakistan', 'Peru', 4),
#  ('South+Africa', 'Mexico', 4),
#  ('Australia', 'Brazil', 4),
#  ('Peru', 'Algeria', 4),
#  ('Tunisia', 'Algeria', 4),
#  ('Denmark', 'France', 4),
#  ('Canada', 'Russia', 4),
#  ('El+Salvador', 'Mexico', 4),
#  ('El+Salvador', 'Guatemala', 4),
#  ('Greece', 'Spain', 4),
#  ('Sweden', 'Germany', 4),
#  ('Oman', 'India', 4),
#  ('Egypt', 'Pakistan', 4),
#  ('Belgium', 'France', 4),
#  ('Azerbaijan', 'Turkey', 4),
#  ('Libya', 'India', 4),
#  ('Ivory+Coast', 'Philippines', 4),
#  ('Ivory+Coast', 'Guinea', 4),
#  ('Ivory+Coast', 'Tanzania', 4),
#  ('Croatia', 'Romania', 4),
#  ('Netherlands', 'United+States', 4),
#  ('Albania', 'Brazil', 4),
#  ('Albania', 'Turkey', 4),
#  ('Dominican+Republic', 'India', 4),
#  ('Kosovo', 'Turkey', 4),
#  ('Cameroon', 'India', 4),
#  ('Cameroon', 'Nigeria', 4),
#  ('Norway', 'Canada', 4),
#  ('Ecuador', 'Brazil', 4),
#  ('Morocco', 'Algeria', 4),
#  ('Morocco', 'Spain', 4),
#  ('Bangladesh', 'Thailand', 4),
#  ('Yemen', 'Tunisia', 4),
#  ('Serbia', 'Hungary', 4),
#  ('Uganda', 'Tanzania', 4),
#  ('Israel', 'Mexico', 4),
#  ('Benin', 'India', 4),
#  ('Benin', 'Ghana', 4),
#  ('Moldova', 'Russia', 4),
#  ('Paraguay', 'Argentina', 4),
#  ('Tajikistan', 'Uzbekistan', 4),
#  ('Uzbekistan', 'Algeria', 4),
#  ('Uzbekistan', 'Mexico', 4),
#  ('Mauritius', 'Brazil', 4),
#  ('Guatemala', 'Brazil', 4),
#  ('Bolivia', 'Mexico', 4),
#  ('United+Arab+Emirates', 'Saudi+Arabia', 4),
#  ('Laos', 'Thailand', 4),
#  ('Haiti', 'Madagascar', 4),
#  ('Kyrgyzstan', 'Uzbekistan', 4),
#  ('Latvia', 'Poland', 4),
#  ('Brazil', 'Italy', 3),
#  ('Brazil', 'Nigeria', 3),
#  ('Brazil', 'Guatemala', 3),
#  ('Thailand', 'Brazil', 3),
#  ('Thailand', 'Spain', 3),
#  ('Algeria', 'South+Africa', 3),
#  ('Algeria', 'Peru', 3),
#  ('China', 'Japan', 3),
#  ('China', 'Madagascar', 3),
#  ('China', 'Indonesia', 3),
#  ('China', 'Colombia', 3),
#  ('South+Korea', 'Brazil', 3),
#  ('Hungary', 'Germany', 3),
#  ('Hungary', 'Slovakia', 3),
#  ('Poland', 'Belgium', 3),
#  ('Venezuela', 'Brazil', 3),
#  ('Venezuela', 'Thailand', 3),
#  ('Venezuela', 'Argentina', 3),
#  ('Venezuela', 'Malaysia', 3),
#  ('Venezuela', 'Peru', 3),
#  ('Germany', 'Spain', 3),
#  ('Germany', 'Ukraine', 3),
#  ('France', 'China', 3),
#  ('France', 'United+States', 3),
#  ('France', 'Switzerland', 3),
#  ('Argentina', 'United+States', 3),
#  ('Russia', 'Mexico', 3),
#  ('Russia', 'Romania', 3),
#  ('Russia', 'Canada', 3),
#  ('Cuba', 'Thailand', 3),
#  ('Cuba', 'Mexico', 3),
#  ('Cuba', 'Philippines', 3),
#  ('Cuba', 'Colombia', 3),
#  ('Mexico', 'Philippines', 3),
#  ('Mexico', 'Australia', 3),
#  ('Japan', 'Spain', 3),
#  ('Ukraine', 'Turkey', 3),
#  ('Italy', 'Thailand', 3),
#  ('Macedonia', 'Turkey', 3),
#  ('India', 'Algeria', 3),
#  ('India', 'South+Korea', 3),
#  ('India', 'Russia', 3),
#  ('India', 'Sri+Lanka', 3),
#  ('India', 'Turkey', 3),
#  ('India', 'Peru', 3),
#  ('India', 'Ethiopia', 3),
#  ('India', 'Nepal', 3),
#  ('Portugal', 'Italy', 3),
#  ('Portugal', 'Madagascar', 3),
#  ('Ghana', 'Ivory+Coast', 3),
#  ('Madagascar', 'Mexico', 3),
#  ('Indonesia', 'Mexico', 3),
#  ('Indonesia', 'Colombia', 3),
#  ('Malaysia', 'Portugal', 3),
#  ('Malaysia', 'Indonesia', 3),
#  ('Czech+Republic', 'United+States', 3),
#  ('Romania', 'Brazil', 3),
#  ('Romania', 'Spain', 3),
#  ('Bulgaria', 'Russia', 3),
#  ('Bulgaria', 'Macedonia', 3),
#  ('Bulgaria', 'Romania', 3),
#  ('Guinea', 'India', 3),
#  ('Colombia', 'India', 3),
#  ('Colombia', 'Peru', 3),
#  ('Vietnam', 'Mexico', 3),
#  ('Vietnam', 'Myanmar', 3),
#  ('Turkey', 'Japan', 3),
#  ('Turkey', 'Ukraine', 3),
#  ('Turkey', 'Iran', 3),
#  ('Pakistan', 'Thailand', 3),
#  ('Pakistan', 'Argentina', 3),
#  ('Pakistan', 'Egypt', 3),
#  ('Chad', 'Tanzania', 3),
#  ('Cambodia', 'Brazil', 3),
#  ('South+Africa', 'Spain', 3),
#  ('South+Africa', 'United+States', 3),
#  ('Australia', 'South+Africa', 3),
#  ('Peru', 'Pakistan', 3),
#  ('Kenya', 'Brazil', 3),
#  ('Tunisia', 'Iran', 3),
#  ('Nigeria', 'Indonesia', 3),
#  ('Iran', 'Peru', 3),
#  ('El+Salvador', 'India', 3),
#  ('Myanmar', 'Thailand', 3),
#  ('Ethiopia', 'Mexico', 3),
#  ('Ethiopia', 'Philippines', 3),
#  ('Sweden', 'Slovakia', 3),
#  ('Sweden', 'Netherlands', 3),
#  ('Azerbaijan', 'Thailand', 3),
#  ('Azerbaijan', 'India', 3),
#  ('Mozambique', 'Tanzania', 3),
#  ('Libya', 'Iran', 3),
#  ('Ivory+Coast', 'Brazil', 3),
#  ('Niger', 'Nigeria', 3),
#  ('Netherlands', 'Canada', 3),
#  ('Tanzania', 'Madagascar', 3),
#  ('Tanzania', 'Kenya', 3),
#  ('Cameroon', 'Ivory+Coast', 3),
#  ('Ecuador', 'Argentina', 3),
#  ('Ecuador', 'Spain', 3),
#  ('Ecuador', 'Indonesia', 3),
#  ('Syria', 'Mexico', 3),
#  ('Syria', 'India', 3),
#  ('Syria', 'Iran', 3),
#  ('Costa+Rica', 'Philippines', 3),
#  ('Bangladesh', 'China', 3),
#  ('Yemen', 'Libya', 3),
#  ('Uganda', 'Brazil', 3),
#  ('Taiwan', 'Mexico', 3),
#  ('Israel', 'Italy', 3),
#  ('Israel', 'United+States', 3),
#  ('Zimbabwe', 'Madagascar', 3),
#  ('Zimbabwe', 'South+Africa', 3),
#  ('Senegal', 'Mexico', 3),
#  ('Senegal', 'Burkina+Faso', 3),
#  ('Senegal', 'Sudan', 3),
#  ('Gambia', 'Tanzania', 3),
#  ('Sudan', 'Pakistan', 3),
#  ('Sudan', 'Niger', 3),
#  ('Georgia', 'Ukraine', 3),
#  ('Kazakhstan', 'Canada', 3),
#  ('Panama', 'Philippines', 3),
#  ('New+Zealand', 'United+States', 3),
#  ('Switzerland', 'Italy', 3),
#  ('Uzbekistan', 'Turkmenistan', 3),
#  ('Guatemala', 'India', 3),
#  ('Bolivia', 'Peru', 3),
#  ('Honduras', 'Philippines', 3),
#  ('Chile', 'Peru', 3),
#  ('Republic+of+the+Congo', 'Democratic+Republic+of+the+Congo', 3),
#  ('Trinidad+and+Tobago', 'India', 3),
#  ('United+Arab+Emirates', 'Iran', 3),
#  ('Saudi+Arabia', 'United+States', 3),
#  ('Hong+Kong', 'China', 3),
#  ('Kyrgyzstan', 'Argentina', 3),
#  ('Burundi', 'Ethiopia', 3),
#  ('Reunion', 'Brazil', 3)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.load('stage-1')

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-6,3e-4))
# Out:
# Total time: 10:22
# epoch  train_loss  valid_loss  error_rate
# 1      1.094779    1.052303    0.296697    (02:34)
# 2      1.048684    0.984621    0.276596    (02:37)
# 3      0.992562    0.951541    0.268365    (02:35)
# 4      0.943050    0.943218    0.266349    (02:34)

# %%
learn.save('resnet34-big-stage2')

# %%
i = 5
img = open_image(learn.path/'train'/os.listdir('../scraper/img/train')[i])
os.listdir('../scraper/img/train')[i]

# %%
img

# %%
learn.predict(img)

# %%
learn.path, learn.model_dir

# %%
get_transforms()

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. Later in the course you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here.

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=299, bs=32)
data.normalize(imagenet_stats)

# %%
learn = ConvLearner(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(1)

# %%
learn.fit_one_cycle(4)

# %%
learn.fit_one_cycle(4)

# %%
learn.fit_one_cycle(4)

# %%
learn.fit_one_cycle(4)

# %%
learn.save('stage-1-50')

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(1, max_lr=slice(1e-6,1e-4))

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))

# %% [markdown]
# In this case it doesn't, so let's go back to our previous model.

# %%
learn.load('stage-1-50')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=1)
